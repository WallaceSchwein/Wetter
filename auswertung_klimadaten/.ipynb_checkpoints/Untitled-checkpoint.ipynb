# %%
import pandas as pd
from datetime import datetime as dt

df = pd.read_csv('clima_data.csv')
df.head()
# Out:
#          Jahr  Temperatur-Minimum(C)  Temperatur-Mittelwert(C)  \
# 0  1948-01-01                   -5.0                      -1.8
# 1  1948-01-02                   -2.7                       4.4
# 2  1948-01-03                    5.2                       8.5
# 3  1948-01-04                    6.6                      10.2
# 4  1948-01-05                    8.0                      10.5
#
#    Temperatur-Maximum(C)  Bodentemperatur-Minimum(C) Sonnenstunden(h)  \
# 0                    0.8                        -4.7              n/A
# 1                    6.8                        -2.5              n/A
# 2                   10.6                         4.6              n/A
# 3                   11.5                         4.7              n/A
# 4                   12.0                         5.9              n/A
#
#   Relative Luftfeuchtigkeit(%) Regen(mm) Niederschlagsform(num) Schnee(cm)  \
# 0                           89       5.7                      8          4
# 1                           95       3.3                      1          8
# 2                           86         4                      1          0
# 3                           83       0.2                      1          0
# 4                           78         2                      1          0
#
#   Neuschnee(cm) Windgeschwindigkeit-Maximum(km/h)  \
# 0           n/A                               n/A
# 1           n/A                               n/A
# 2           n/A                               n/A
# 3           n/A                               n/A
# 4           n/A                               n/A
#
#   Windgeschwindigkeit-Mittelwert(km/h)
# 0                                  n/A
# 1                                  n/A
# 2                                  n/A
# 3                                  n/A
# 4                                  n/A

# %%
temp = []
yr = []

for pos, d in df.iterrows():
    temp.append(d["Temperatur-Mittelwert(C)"])
    yr.append(d["Jahr"])

# %%
min = -20.0
i = 0
for pos, d in df.iterrows():
    if d["Temperatur-Minimum(C)"] < min:
        min = d["Temperatur-Minimum(C)"]
        i = pos
print(i)
